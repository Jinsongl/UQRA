# %%
# %matplotlib notebook
import numpy as np
import csv
import chaospy as cp
import os
from datetime import datetime
import matplotlib.pyplot as plt

# %%
pltlinestyles = [ (0, (1, 5)),(0, (3, 5, 1, 5)),(0, (5, 5)),(0, ()), (0, (3, 1, 1, 1, 1, 1)), 
        (0, (5, 10)), (0, (3, 10, 1, 10)), (0, (3, 10, 1, 10, 1, 10)),(0, (1, 10)), 
        (0, (5, 1)),  (0, (3, 1, 1, 1)),(0, (3, 5, 1, 5, 1, 5)),  (0, (1, 1))  ]*10

pltmarkers =['o','v','s','d','+','*']
ordinal = lambda n: "%d%s" % (n,"tsnrhtdd"[(math.floor(n/10)%10!=1)*(n%10<4)*n%10::4])
pltcolors = plt.rcParams['axes.prop_cycle'].by_key()['color']
figsize = (4*1.5,3*1.5)
pltlinewidth = 1.5

# %%
from statsmodels.distributions.empirical_distribution import ECDF
import pandas as pd
from pandas.core.sparse.frame import SparseDataFrame
if not None:
    print('1')
# Out:
# 1

# %%
powerspecturms2test = ['jonswap', 'spec_test1']
powerspecturms_args = [(8, 10), 2]
for arg, psd in zip(powerspecturms_args, powerspecturms2test):
    print(arg, psd)
# Out:
# (8, 10) jonswap
# 2 spec_test1

# %%
a = np.arange(10).reshape(5,2)
b = np.arange(5)[:,np.newaxis]
c = np.concatenate((a,b),axis=1)
d = c[2,:]
print(c.shape)
print(d.shape)
# Out:
# (5, 3)
# (3,)

# %%
psd_f = np.load('jonswap_psd_f.npy')
psd_pxx = np.load('jonswap_psd_pxx.npy')
tau  = np.load('jonswap_tau.npy')
acf   = np.load('jonswap_acf.npy')
t  = np.load('jonswap_t.npy')
eta   = np.load('jonswap_eta.npy')
print(psd_f.shape)
print(psd_pxx.shape)
print(tau.shape)
print(acf.shape)
print(t.shape)
print(eta.shape)
plt.figure(1)
plt.plot(psd_f,psd_pxx);
plt.figure(2)
plt.plot(tau, acf,'*')
plt.figure(3)
plt.plot(t, eta)
# plt.xlim(0,1)
# Out:
# (10000,)
# (10000,)
# (19999,)
# (19999,)
# (10000,)
# (10000,)
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
sdof_time = np.load('sdof_time.npy')
sdof_freq = np.load('sdof_frequency.npy')
print(sdof_time.shape)
print(sdof_freq.shape)
# Out:
# (10001, 3)
# (10001, 3)

# %%
fig1, axs = plt.subplots(2,1)
axs[0].plot(sdof_time[:,0],sdof_time[:,1], label=r'$x(t)$',color=pltcolors[0],linewidth=pltlinewidth)
axs[1].plot(sdof_time[:,0],sdof_time[:,2], label=r'$y(t)$',color=pltcolors[1],linewidth=pltlinewidth);
axs[0].set_xlim(0,1000)
axs[1].set_xlim(0,1000)
axs[0].legend()
axs[1].legend()
fig2, ax2 = plt.subplots()
ax2.plot(sdof_freq[:,0],sdof_freq[:,1:3]);
ax2.set_xlim(0,0.5)
ax2.set_xlabel(r'frequency ($Hz$)')
ax2.set_ylabel(r'$U^2/Hz$')
# fig, ax1 = plt.subplots()

# color = 'tab:red'
# ax1.set_xlabel('frequency (Hz)')
# ax1.set_ylabel('input')
# ax1.plot(sdof_freq[:,0],sdof_freq[:,1],'r')

# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# color = 'tab:blue'
# ax2.set_ylabel('output')  # we already handled the x-label with ax1
# ax2.plot(sdof_freq[:,0],sdof_freq[:,2])

# plot.tight_layout()  # otherwise the right y-label is slightly clipped
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, '$U^2/Hz$')

# %%
print(dir(psd_f))
print(str(psd_f))
# Out:
# ['T', '__abs__', '__add__', '__and__', '__array__', '__array_finalize__', '__array_function__', '__array_interface__', '__array_prepare__', '__array_priority__', '__array_struct__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__complex__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__ilshift__', '__imatmul__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshif
# ...

# %%
from scipy.stats import moment

# %%
moment(np.arange(10).reshape(5,2), moment=[1,2])b

# %%
signal = np.array([-2, 8, 6, 4, 1, 0, 3, 5], dtype=float)
fourier = np.fft.fft(signal)
n = signal.size
timestep = 0.1
freq = np.fft.fftfreq(n, d=timestep)
freq

# %%
[print(i%2) for i in range(1,10)]
[print(i//2) for i in range(1,10)]

# %%
a = np.arange(10)
b = np.arange(10)
print(np.array_equal(a,b))

# %%
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,
                                              ExpSineSquared, DotProduct,
                                              ConstantKernel,WhiteKernel)

# %%
dist_gamma = cp.Gamma(1,2)
print(dir(dist_gamma))
for i in range(1,4):
    print(dist_gamma.mom(i))

# %%
distribution = cp.Uniform(0,10)
q = np.linspace(0,1,6)[1:-1]
print(np.around(q,4))
q_inv = distribution.inv(q)
print(np.around(q_inv, 4))
q_inv_fwd = distribution.fwd(q_inv)
print(np.around(q_inv_fwd, 4))

# %%
f = np.load('time.npy')
print(f.shape)
print(len(f))
print(f[0],f[-1],f[1]-f[0])
plt.plot(f[:,0],f[:,1:3]);

# %%
t = np.load('frequency.npy')
# print(t.shape)
# print(t[0],t[-1],t[1]-t[0])
plt.plot(t[:,0],t[:,1:3]);
print(4*np.std(t[:,1])**2)

# %%
dir(RBF)
kernel = 1.0 * RBF(length_scale=100.0, length_scale_bounds=(1e-2, 1e3))
print(kernel)
# RBF.get_params()
# print(RBF.__str__)

# %%
a = np.arange(3).T
print(a.shape)
b = a[:,np.newaxis]
print(b.shape)

# %%
dist_x = cp.Iid(cp.Uniform(),3)
print(type(cp.Normal()))
print(type(dist_x))

# %%
def __num2str__(n):
    if n<100:
        return '{:2d}'.format(n)
    else:
        __str ='{:.0E}'.format(n) 
        return __str[0]+'E'+__str[-1] 
a = [100,10000,1000000]
b = list(map(__num2str__, a))

# %%
dataset = np.load('Train_Free_MCS1_DoE1.npy')
x, y, z = dataset
print(dataset.shape)
print(x.shape)
print(y.shape)
print(z.shape)

# %%
dist_x = cp.J(cp.Uniform(),cp.Uniform(),cp.Uniform())
samples = dist_x.sample(10000,rule='R')
print(dist_x)
print(samples)

# %%
print(b)

# %%
a = np.arange(4).reshape(2,2)
b = np.arange(4).reshape(2,2)
# la = list(*(a[0,:])
lb = list(*(b[:,0])
# print(la)
print(lb)
# print(la+lb)

# %%
print(os.getcwd())
a = np.loadtxt('DoE_MC_R_10.txt')
b = np.loadtxt('/Users/jinsongliu/External/MUSE_UQ_DATA/Ishigami/Data/DoE_MC_R_10.txt')
print(a.shape)
a = np.load('DoE_MC_R_1E2.npy')
print(a.shape)

# %%
a = np.arange(10).reshape(2,5)
print(a.size)
print(len(a))
print(a)
for ia in a:
    print(ia)
print([None,'1','h'])

# %%
now = datetime.now()
print(datetime.now())
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print(dt_string)

# %%
a = None
b = ['a','c']
c = np.array([1,2,3])
l1 = [None]
l2 = list(c)
l = l1 + l2
print(l)

# %%
with open("result.txt", "wb") as result:
    writer = csv.writer(result, delimiter=';')
    writer.writerows(l)

# %%
with open('test1.text','w') as filein:
    filein.write('\t'.join(map(repr, l)))

# %%
with open('test1.text','r') as filein:
    for line in filein:
        x = line.split('\t')
        print(line)
        print(x)
        y = np.array(x[2]) * 2
        print(y)
        print(len(line))
